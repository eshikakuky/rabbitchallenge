# %% [markdown]
# # 準備

# %% [markdown]
# ## Googleドライブのマウント

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## sys.pathの設定

# %% [markdown]
# 以下では，Googleドライブのマイドライブ直下にDNN_codeフォルダを置くことを仮定しています．必要に応じて，パスを変更してください．

# %%
import sys
sys.path.append('/content/drive/My Drive/DNN_code_colab_lesson_1_2')
sys.path.append('/content/drive/My Drive/DNN_code_colab_lesson_1_2/lesson_2')

# %% [markdown]
# # optimizer

# %% [markdown]
# ## SGD

# %%
import sys, os
sys.path.append(os.pardir)  # 親ディレクトリのファイルをインポートするための設定
import numpy as np
from collections import OrderedDict
from common import layers
from data.mnist import load_mnist
import matplotlib.pyplot as plt
from multi_layer_net import MultiLayerNet


# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================


network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
#learning_rate = 0.01
learning_rate = 0.05


train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        network.params[key] -= learning_rate * grad[key]
        
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
    
    
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
    if (i + 1) > 990:
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))

        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 991. 正答率(トレーニング) = 0.13
#                 : 991. 正答率(テスト) = 0.1135
# Generation: 992. 正答率(トレーニング) = 0.13
#                 : 992. 正答率(テスト) = 0.1135
# Generation: 993. 正答率(トレーニング) = 0.13
#                 : 993. 正答率(テスト) = 0.1135
# Generation: 994. 正答率(トレーニング) = 0.13
#                 : 994. 正答率(テスト) = 0.1135
# Generation: 995. 正答率(トレーニング) = 0.13
#                 : 995. 正答率(テスト) = 0.1135
# Generation: 996. 正答率(トレーニング) = 0.13
#                 : 996. 正答率(テスト) = 0.1135
# Generation: 997. 正答率(トレーニング) = 0.13
#                 : 997. 正答率(テスト) = 0.1135
# Generation: 998. 正答率(トレーニング) = 0.13
#                 : 998. 正答率(テスト) = 0.1135
# Generation: 999. 正答率(トレーニング) = 0.13
#                 : 999. 正答率(テスト) = 0.1135
# Generation: 1000. 正答率(トレーニング) = 0.08
#                 : 1000. 正答率(テスト) = 0.1135

# %% [markdown]
# ## Momentum

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
# 慣性
momentum = 0.9

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        v = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            v[key] = np.zeros_like(network.params[key])
        v[key] = momentum * v[key] - learning_rate * grad[key]
        network.params[key] += v[key]

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

    if (i + 1) > 990:
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
    
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 901. 正答率(トレーニング) = 0.11
#                 : 901. 正答率(テスト) = 0.1135
# Generation: 902. 正答率(トレーニング) = 0.11
#                 : 902. 正答率(テスト) = 0.1135
# Generation: 903. 正答率(トレーニング) = 0.11
#                 : 903. 正答率(テスト) = 0.1135
# Generation: 904. 正答率(トレーニング) = 0.11
#                 : 904. 正答率(テスト) = 0.1135
# Generation: 905. 正答率(トレーニング) = 0.11
#                 : 905. 正答率(テスト) = 0.1135
# Generation: 906. 正答率(トレーニング) = 0.11
#                 : 906. 正答率(テスト) = 0.1135
# Generation: 907. 正答率(トレーニング) = 0.11
#                 : 907. 正答率(テスト) = 0.1135
# Generation: 908. 正答率(トレーニング) = 0.11
#                 : 908. 正答率(テスト) = 0.1135
# Generation: 909. 正答率(トレーニング) = 0.11
#                 : 909. 正答率(テスト) = 0.1135
# Generation: 910. 正答率(トレーニング) = 0.11
#                 : 910. 正答率(テスト) = 0.1135
# Generation: 911. 正答率(トレーニング) = 0.11
#                 : 911. 正答率(テスト) = 0.1135
# Generation: 912. 正答率(トレーニング) = 0.11
#                 : 912. 正答率(テスト) = 0.1135
# Generation: 913. 正答率(トレーニング) = 0.11
#                 : 913. 正答率(テスト) = 0.1135
# Generation: 914. 正答率(トレーニング) = 0.11
#                 : 914. 正答率(テスト) = 0.1135
# Generation: 915. 正答率(トレーニング) = 0.11
#                 : 915. 正答率(テスト) = 0.1135
# Generation: 916. 正答率(トレーニング) = 0.11
#                 : 916. 正答率(テスト) = 0.1135
# Generation: 917. 正答率(トレーニング) = 0.11
#                 : 917. 正答率(テスト) = 0.1135
# Generation: 918. 正答率(トレーニング) = 0.11
#                 : 918. 正答率(テスト) = 0.1135
# Generation: 919. 正答率(トレーニング) = 0.11
#                 : 919. 正答率(テスト) = 0.1135
# Generation: 920. 正答率(トレーニング) = 0.07
#                 : 920. 正答率(テスト) = 0.1135
# Generation: 921. 正答率(トレーニング) = 0.07
#                 : 921. 正答率(テスト) = 0.1135
# Generation: 922. 正答率(トレーニング) = 0.07
#                 : 922. 正答率(テスト) = 0.1135
# Generation: 923. 正答率(トレーニング) = 0.07
#                 : 923. 正答率(テスト) = 0.1135
# Generation: 924. 正答率(トレーニング) = 0.07
#                 : 924. 正答率(テスト) = 0.1135
# Generation: 925. 正答率(トレーニング) = 0.07
#                 : 925. 正答率(テスト) = 0.1135
# Generation: 926. 正答率(トレーニング) = 0.07
#                 : 926. 正答率(テスト) = 0.1135
# Generation: 927. 正答率(トレーニング) = 0.07
#                 : 927. 正答率(テスト) = 0.1135
# Generation: 928. 正答率(トレーニング) = 0.07
#                 : 928. 正答率(テスト) = 0.1135
# Generation: 929. 正答率(トレーニング) = 0.07
#                 : 929. 正答率(テスト) = 0.1135
# Generation: 930. 正答率(トレーニング) = 0.08
#                 : 930. 正答率(テスト) = 0.1135
# Generation: 931. 正答率(トレーニング) = 0.08
#                 : 931. 正答率(テスト) = 0.1135
# Generation: 932. 正答率(トレーニング) = 0.08
#                 : 932. 正答率(テスト) = 0.1135
# Generation: 933. 正答率(トレーニング) = 0.08
#                 : 933. 正答率(テスト) = 0.1135
# Generation: 934. 正答率(トレーニング) = 0.08
#                 : 934. 正答率(テスト) = 0.1135
# Generation: 935. 正答率(トレーニング) = 0.08
#                 : 935. 正答率(テスト) = 0.1135
# Generation: 936. 正答率(トレーニング) = 0.08
#                 : 936. 正答率(テスト) = 0.1135
# Generation: 937. 正答率(トレーニング) = 0.08
#                 : 937. 正答率(テスト) = 0.1135
# Generation: 938. 正答率(トレーニング) = 0.08
#                 : 938. 正答率(テスト) = 0.1135
# Generation: 939. 正答率(トレーニング) = 0.08
#                 : 939. 正答率(テスト) = 0.1135
# Generation: 940. 正答率(トレーニング) = 0.09
#                 : 940. 正答率(テスト) = 0.1135
# Generation: 941. 正答率(トレーニング) = 0.09
#                 : 941. 正答率(テスト) = 0.1135
# Generation: 942. 正答率(トレーニング) = 0.09
#                 : 942. 正答率(テスト) = 0.1135
# Generation: 943. 正答率(トレーニング) = 0.09
#                 : 943. 正答率(テスト) = 0.1135
# Generation: 944. 正答率(トレーニング) = 0.09
#                 : 944. 正答率(テスト) = 0.1135
# Generation: 945. 正答率(トレーニング) = 0.09
#                 : 945. 正答率(テスト) = 0.1135
# Generation: 946. 正答率(トレーニング) = 0.09
#                 : 946. 正答率(テスト) = 0.1135
# Generation: 947. 正答率(トレーニング) = 0.09
#                 : 947. 正答率(テスト) = 0.1135
# Generation: 948. 正答率(トレーニング) = 0.09
#                 : 948. 正答率(テスト) = 0.1135
# Generation: 949. 正答率(トレーニング) = 0.09
#                 : 949. 正答率(テスト) = 0.1135
# Generation: 950. 正答率(トレーニング) = 0.11
#                 : 950. 正答率(テスト) = 0.1135
# Generation: 951. 正答率(トレーニング) = 0.11
#                 : 951. 正答率(テスト) = 0.1135
# Generation: 952. 正答率(トレーニング) = 0.11
#                 : 952. 正答率(テスト) = 0.1135
# Generation: 953. 正答率(トレーニング) = 0.11
#                 : 953. 正答率(テスト) = 0.1135
# Generation: 954. 正答率(トレーニング) = 0.11
#                 : 954. 正答率(テスト) = 0.1135
# Generation: 955. 正答率(トレーニング) = 0.11
#                 : 955. 正答率(テスト) = 0.1135
# Generation: 956. 正答率(トレーニング) = 0.11
#                 : 956. 正答率(テスト) = 0.1135
# Generation: 957. 正答率(トレーニング) = 0.11
#                 : 957. 正答率(テスト) = 0.1135
# Generation: 958. 正答率(トレーニング) = 0.11
#                 : 958. 正答率(テスト) = 0.1135
# Generation: 959. 正答率(トレーニング) = 0.11
#                 : 959. 正答率(テスト) = 0.1135
# Generation: 960. 正答率(トレーニング) = 0.12
#                 : 960. 正答率(テスト) = 0.1135
# Generation: 961. 正答率(トレーニング) = 0.12
#                 : 961. 正答率(テスト) = 0.1135
# Generation: 962. 正答率(トレーニング) = 0.12
#                 : 962. 正答率(テスト) = 0.1135
# Generation: 963. 正答率(トレーニング) = 0.12
#                 : 963. 正答率(テスト) = 0.1135
# Generation: 964. 正答率(トレーニング) = 0.12
#                 : 964. 正答率(テスト) = 0.1135
# Generation: 965. 正答率(トレーニング) = 0.12
#                 : 965. 正答率(テスト) = 0.1135
# Generation: 966. 正答率(トレーニング) = 0.12
#                 : 966. 正答率(テスト) = 0.1135
# Generation: 967. 正答率(トレーニング) = 0.12
#                 : 967. 正答率(テスト) = 0.1135
# Generation: 968. 正答率(トレーニング) = 0.12
#                 : 968. 正答率(テスト) = 0.1135
# Generation: 969. 正答率(トレーニング) = 0.12
#                 : 969. 正答率(テスト) = 0.1135
# Generation: 970. 正答率(トレーニング) = 0.09
#                 : 970. 正答率(テスト) = 0.1135
# Generation: 971. 正答率(トレーニング) = 0.09
#                 : 971. 正答率(テスト) = 0.1135
# Generation: 972. 正答率(トレーニング) = 0.09
#                 : 972. 正答率(テスト) = 0.1135
# Generation: 973. 正答率(トレーニング) = 0.09
#                 : 973. 正答率(テスト) = 0.1135
# Generation: 974. 正答率(トレーニング) = 0.09
#                 : 974. 正答率(テスト) = 0.1135
# Generation: 975. 正答率(トレーニング) = 0.09
#                 : 975. 正答率(テスト) = 0.1135
# Generation: 976. 正答率(トレーニング) = 0.09
#                 : 976. 正答率(テスト) = 0.1135
# Generation: 977. 正答率(トレーニング) = 0.09
#                 : 977. 正答率(テスト) = 0.1135
# Generation: 978. 正答率(トレーニング) = 0.09
#                 : 978. 正答率(テスト) = 0.1135
# Generation: 979. 正答率(トレーニング) = 0.09
#                 : 979. 正答率(テスト) = 0.1135
# Generation: 980. 正答率(トレーニング) = 0.08
#                 : 980. 正答率(テスト) = 0.1135
# Generation: 981. 正答率(トレーニング) = 0.08
#                 : 981. 正答率(テスト) = 0.1135
# Generation: 982. 正答率(トレーニング) = 0.08
#                 : 982. 正答率(テスト) = 0.1135
# Generation: 983. 正答率(トレーニング) = 0.08
#                 : 983. 正答率(テスト) = 0.1135
# Generation: 984. 正答率(トレーニング) = 0.08
#                 : 984. 正答率(テスト) = 0.1135
# Generation: 985. 正答率(トレーニング) = 0.08
#                 : 985. 正答率(テスト) = 0.1135
# Generation: 986. 正答率(トレーニング) = 0.08
#                 : 986. 正答率(テスト) = 0.1135
# Generation: 987. 正答率(トレーニング) = 0.08
#                 : 987. 正答率(テスト) = 0.1135
# Generation: 988. 正答率(トレーニング) = 0.08
#                 : 988. 正答率(テスト) = 0.1135
# Generation: 989. 正答率(トレーニング) = 0.08
#                 : 989. 正答率(テスト) = 0.1135
# Generation: 990. 正答率(トレーニング) = 0.11
#                 : 990. 正答率(テスト) = 0.101
# Generation: 991. 正答率(トレーニング) = 0.11
#                 : 991. 正答率(テスト) = 0.101
# Generation: 992. 正答率(トレーニング) = 0.11
#                 : 992. 正答率(テスト) = 0.101
# Generation: 993. 正答率(トレーニング) = 0.11
#                 : 993. 正答率(テスト) = 0.101
# Generation: 994. 正答率(トレーニング) = 0.11
#                 : 994. 正答率(テスト) = 0.101
# Generation: 995. 正答率(トレーニング) = 0.11
#                 : 995. 正答率(テスト) = 0.101
# Generation: 996. 正答率(トレーニング) = 0.11
#                 : 996. 正答率(テスト) = 0.101
# Generation: 997. 正答率(トレーニング) = 0.11
#                 : 997. 正答率(テスト) = 0.101
# Generation: 998. 正答率(トレーニング) = 0.11
#                 : 998. 正答率(テスト) = 0.101
# Generation: 999. 正答率(トレーニング) = 0.11
#                 : 999. 正答率(テスト) = 0.101
# Generation: 1000. 正答率(トレーニング) = 0.15
#                 : 1000. 正答率(テスト) = 0.101

# %% [markdown]
# ## MomentumをもとにAdaGradを作ってみよう
# θ = 1e-4 とする

# %%
# AdaGradを作ってみよう
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
# iters_num = 500 # 処理を短縮

train_size = x_train.shape[0]
batch_size = 100
#learning_rate = 0.01
#learning_rate = 0.02
#learning_rate = 0.03
learning_rate = 0.04


# AdaGradでは不必要
# =============================

# momentum = 0.9 

# =============================

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
            
        # 変更しよう  
        # ===========================================
        #if i == 0:
        #    h[key] = np.zeros_like(network.params[key])        
        #h[key] = momentum * h[key] - learning_rate * grad[key]
        #network.params[key] += h[key]
        # ===========================================

        # revise AdaGrad
        if i == 0:
          h[key] = np.zeros_like(network.params[key]) 
        h[key] += grad[key] * grad[key]
        network.params[key] -= learning_rate * grad[key] / (np.sqrt(h[key]) + 1e-7)


        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)

    if (i + 1) > 990:
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 991. 正答率(トレーニング) = 0.96
#                 : 991. 正答率(テスト) = 0.9234
# Generation: 992. 正答率(トレーニング) = 0.96
#                 : 992. 正答率(テスト) = 0.9234
# Generation: 993. 正答率(トレーニング) = 0.96
#                 : 993. 正答率(テスト) = 0.9234
# Generation: 994. 正答率(トレーニング) = 0.96
#                 : 994. 正答率(テスト) = 0.9234
# Generation: 995. 正答率(トレーニング) = 0.96
#                 : 995. 正答率(テスト) = 0.9234
# Generation: 996. 正答率(トレーニング) = 0.96
#                 : 996. 正答率(テスト) = 0.9234
# Generation: 997. 正答率(トレーニング) = 0.96
#                 : 997. 正答率(テスト) = 0.9234
# Generation: 998. 正答率(トレーニング) = 0.96
#                 : 998. 正答率(テスト) = 0.9234
# Generation: 999. 正答率(トレーニング) = 0.96
#                 : 999. 正答率(テスト) = 0.9234
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.9223

# %% [markdown]
# ## RSMprop

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
decay_rate = 0.99

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        h = {}
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            h[key] = np.zeros_like(network.params[key])
        h[key] *= decay_rate
        h[key] += (1 - decay_rate) * np.square(grad[key])
        network.params[key] -= learning_rate * grad[key] / (np.sqrt(h[key]) + 1e-7)

        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)                
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        
    if (i + 1) > 990:
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
        
        
lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 901. 正答率(トレーニング) = 0.98
#                 : 901. 正答率(テスト) = 0.9358
# Generation: 902. 正答率(トレーニング) = 0.98
#                 : 902. 正答率(テスト) = 0.9358
# Generation: 903. 正答率(トレーニング) = 0.98
#                 : 903. 正答率(テスト) = 0.9358
# Generation: 904. 正答率(トレーニング) = 0.98
#                 : 904. 正答率(テスト) = 0.9358
# Generation: 905. 正答率(トレーニング) = 0.98
#                 : 905. 正答率(テスト) = 0.9358
# Generation: 906. 正答率(トレーニング) = 0.98
#                 : 906. 正答率(テスト) = 0.9358
# Generation: 907. 正答率(トレーニング) = 0.98
#                 : 907. 正答率(テスト) = 0.9358
# Generation: 908. 正答率(トレーニング) = 0.98
#                 : 908. 正答率(テスト) = 0.9358
# Generation: 909. 正答率(トレーニング) = 0.98
#                 : 909. 正答率(テスト) = 0.9358
# Generation: 910. 正答率(トレーニング) = 0.98
#                 : 910. 正答率(テスト) = 0.9292
# Generation: 911. 正答率(トレーニング) = 0.98
#                 : 911. 正答率(テスト) = 0.9292
# Generation: 912. 正答率(トレーニング) = 0.98
#                 : 912. 正答率(テスト) = 0.9292
# Generation: 913. 正答率(トレーニング) = 0.98
#                 : 913. 正答率(テスト) = 0.9292
# Generation: 914. 正答率(トレーニング) = 0.98
#                 : 914. 正答率(テスト) = 0.9292
# Generation: 915. 正答率(トレーニング) = 0.98
#                 : 915. 正答率(テスト) = 0.9292
# Generation: 916. 正答率(トレーニング) = 0.98
#                 : 916. 正答率(テスト) = 0.9292
# Generation: 917. 正答率(トレーニング) = 0.98
#                 : 917. 正答率(テスト) = 0.9292
# Generation: 918. 正答率(トレーニング) = 0.98
#                 : 918. 正答率(テスト) = 0.9292
# Generation: 919. 正答率(トレーニング) = 0.98
#                 : 919. 正答率(テスト) = 0.9292
# Generation: 920. 正答率(トレーニング) = 0.98
#                 : 920. 正答率(テスト) = 0.9404
# Generation: 921. 正答率(トレーニング) = 0.98
#                 : 921. 正答率(テスト) = 0.9404
# Generation: 922. 正答率(トレーニング) = 0.98
#                 : 922. 正答率(テスト) = 0.9404
# Generation: 923. 正答率(トレーニング) = 0.98
#                 : 923. 正答率(テスト) = 0.9404
# Generation: 924. 正答率(トレーニング) = 0.98
#                 : 924. 正答率(テスト) = 0.9404
# Generation: 925. 正答率(トレーニング) = 0.98
#                 : 925. 正答率(テスト) = 0.9404
# Generation: 926. 正答率(トレーニング) = 0.98
#                 : 926. 正答率(テスト) = 0.9404
# Generation: 927. 正答率(トレーニング) = 0.98
#                 : 927. 正答率(テスト) = 0.9404
# Generation: 928. 正答率(トレーニング) = 0.98
#                 : 928. 正答率(テスト) = 0.9404
# Generation: 929. 正答率(トレーニング) = 0.98
#                 : 929. 正答率(テスト) = 0.9404
# Generation: 930. 正答率(トレーニング) = 1.0
#                 : 930. 正答率(テスト) = 0.943
# Generation: 931. 正答率(トレーニング) = 1.0
#                 : 931. 正答率(テスト) = 0.943
# Generation: 932. 正答率(トレーニング) = 1.0
#                 : 932. 正答率(テスト) = 0.943
# Generation: 933. 正答率(トレーニング) = 1.0
#                 : 933. 正答率(テスト) = 0.943
# Generation: 934. 正答率(トレーニング) = 1.0
#                 : 934. 正答率(テスト) = 0.943
# Generation: 935. 正答率(トレーニング) = 1.0
#                 : 935. 正答率(テスト) = 0.943
# Generation: 936. 正答率(トレーニング) = 1.0
#                 : 936. 正答率(テスト) = 0.943
# Generation: 937. 正答率(トレーニング) = 1.0
#                 : 937. 正答率(テスト) = 0.943
# Generation: 938. 正答率(トレーニング) = 1.0
#                 : 938. 正答率(テスト) = 0.943
# Generation: 939. 正答率(トレーニング) = 1.0
#                 : 939. 正答率(テスト) = 0.943
# Generation: 940. 正答率(トレーニング) = 0.98
#                 : 940. 正答率(テスト) = 0.9414
# Generation: 941. 正答率(トレーニング) = 0.98
#                 : 941. 正答率(テスト) = 0.9414
# Generation: 942. 正答率(トレーニング) = 0.98
#                 : 942. 正答率(テスト) = 0.9414
# Generation: 943. 正答率(トレーニング) = 0.98
#                 : 943. 正答率(テスト) = 0.9414
# Generation: 944. 正答率(トレーニング) = 0.98
#                 : 944. 正答率(テスト) = 0.9414
# Generation: 945. 正答率(トレーニング) = 0.98
#                 : 945. 正答率(テスト) = 0.9414
# Generation: 946. 正答率(トレーニング) = 0.98
#                 : 946. 正答率(テスト) = 0.9414
# Generation: 947. 正答率(トレーニング) = 0.98
#                 : 947. 正答率(テスト) = 0.9414
# Generation: 948. 正答率(トレーニング) = 0.98
#                 : 948. 正答率(テスト) = 0.9414
# Generation: 949. 正答率(トレーニング) = 0.98
#                 : 949. 正答率(テスト) = 0.9414
# Generation: 950. 正答率(トレーニング) = 0.99
#                 : 950. 正答率(テスト) = 0.9422
# Generation: 951. 正答率(トレーニング) = 0.99
#                 : 951. 正答率(テスト) = 0.9422
# Generation: 952. 正答率(トレーニング) = 0.99
#                 : 952. 正答率(テスト) = 0.9422
# Generation: 953. 正答率(トレーニング) = 0.99
#                 : 953. 正答率(テスト) = 0.9422
# Generation: 954. 正答率(トレーニング) = 0.99
#                 : 954. 正答率(テスト) = 0.9422
# Generation: 955. 正答率(トレーニング) = 0.99
#                 : 955. 正答率(テスト) = 0.9422
# Generation: 956. 正答率(トレーニング) = 0.99
#                 : 956. 正答率(テスト) = 0.9422
# Generation: 957. 正答率(トレーニング) = 0.99
#                 : 957. 正答率(テスト) = 0.9422
# Generation: 958. 正答率(トレーニング) = 0.99
#                 : 958. 正答率(テスト) = 0.9422
# Generation: 959. 正答率(トレーニング) = 0.99
#                 : 959. 正答率(テスト) = 0.9422
# Generation: 960. 正答率(トレーニング) = 0.96
#                 : 960. 正答率(テスト) = 0.9387
# Generation: 961. 正答率(トレーニング) = 0.96
#                 : 961. 正答率(テスト) = 0.9387
# Generation: 962. 正答率(トレーニング) = 0.96
#                 : 962. 正答率(テスト) = 0.9387
# Generation: 963. 正答率(トレーニング) = 0.96
#                 : 963. 正答率(テスト) = 0.9387
# Generation: 964. 正答率(トレーニング) = 0.96
#                 : 964. 正答率(テスト) = 0.9387
# Generation: 965. 正答率(トレーニング) = 0.96
#                 : 965. 正答率(テスト) = 0.9387
# Generation: 966. 正答率(トレーニング) = 0.96
#                 : 966. 正答率(テスト) = 0.9387
# Generation: 967. 正答率(トレーニング) = 0.96
#                 : 967. 正答率(テスト) = 0.9387
# Generation: 968. 正答率(トレーニング) = 0.96
#                 : 968. 正答率(テスト) = 0.9387
# Generation: 969. 正答率(トレーニング) = 0.96
#                 : 969. 正答率(テスト) = 0.9387
# Generation: 970. 正答率(トレーニング) = 0.96
#                 : 970. 正答率(テスト) = 0.9422
# Generation: 971. 正答率(トレーニング) = 0.96
#                 : 971. 正答率(テスト) = 0.9422
# Generation: 972. 正答率(トレーニング) = 0.96
#                 : 972. 正答率(テスト) = 0.9422
# Generation: 973. 正答率(トレーニング) = 0.96
#                 : 973. 正答率(テスト) = 0.9422
# Generation: 974. 正答率(トレーニング) = 0.96
#                 : 974. 正答率(テスト) = 0.9422
# Generation: 975. 正答率(トレーニング) = 0.96
#                 : 975. 正答率(テスト) = 0.9422
# Generation: 976. 正答率(トレーニング) = 0.96
#                 : 976. 正答率(テスト) = 0.9422
# Generation: 977. 正答率(トレーニング) = 0.96
#                 : 977. 正答率(テスト) = 0.9422
# Generation: 978. 正答率(トレーニング) = 0.96
#                 : 978. 正答率(テスト) = 0.9422
# Generation: 979. 正答率(トレーニング) = 0.96
#                 : 979. 正答率(テスト) = 0.9422
# Generation: 980. 正答率(トレーニング) = 0.99
#                 : 980. 正答率(テスト) = 0.9426
# Generation: 981. 正答率(トレーニング) = 0.99
#                 : 981. 正答率(テスト) = 0.9426
# Generation: 982. 正答率(トレーニング) = 0.99
#                 : 982. 正答率(テスト) = 0.9426
# Generation: 983. 正答率(トレーニング) = 0.99
#                 : 983. 正答率(テスト) = 0.9426
# Generation: 984. 正答率(トレーニング) = 0.99
#                 : 984. 正答率(テスト) = 0.9426
# Generation: 985. 正答率(トレーニング) = 0.99
#                 : 985. 正答率(テスト) = 0.9426
# Generation: 986. 正答率(トレーニング) = 0.99
#                 : 986. 正答率(テスト) = 0.9426
# Generation: 987. 正答率(トレーニング) = 0.99
#                 : 987. 正答率(テスト) = 0.9426
# Generation: 988. 正答率(トレーニング) = 0.99
#                 : 988. 正答率(テスト) = 0.9426
# Generation: 989. 正答率(トレーニング) = 0.99
#                 : 989. 正答率(テスト) = 0.9426
# Generation: 990. 正答率(トレーニング) = 1.0
#                 : 990. 正答率(テスト) = 0.9462
# Generation: 991. 正答率(トレーニング) = 1.0
#                 : 991. 正答率(テスト) = 0.9462
# Generation: 992. 正答率(トレーニング) = 1.0
#                 : 992. 正答率(テスト) = 0.9462
# Generation: 993. 正答率(トレーニング) = 1.0
#                 : 993. 正答率(テスト) = 0.9462
# Generation: 994. 正答率(トレーニング) = 1.0
#                 : 994. 正答率(テスト) = 0.9462
# Generation: 995. 正答率(トレーニング) = 1.0
#                 : 995. 正答率(テスト) = 0.9462
# Generation: 996. 正答率(トレーニング) = 1.0
#                 : 996. 正答率(テスト) = 0.9462
# Generation: 997. 正答率(トレーニング) = 1.0
#                 : 997. 正答率(テスト) = 0.9462
# Generation: 998. 正答率(トレーニング) = 1.0
#                 : 998. 正答率(テスト) = 0.9462
# Generation: 999. 正答率(トレーニング) = 1.0
#                 : 999. 正答率(テスト) = 0.9462
# Generation: 1000. 正答率(トレーニング) = 0.98
#                 : 1000. 正答率(テスト) = 0.9466

# %% [markdown]
# ## Adam

# %%
# データの読み込み
(x_train, d_train), (x_test, d_test) = load_mnist(normalize=True, one_hot_label=True)

print("データ読み込み完了")

# batch_normalizationの設定 ================================
# use_batchnorm = True
use_batchnorm = False
# ====================================================

network = MultiLayerNet(input_size=784, hidden_size_list=[40, 20], output_size=10, activation='sigmoid', weight_init_std=0.01,
                       use_batchnorm=use_batchnorm)

iters_num = 1000
train_size = x_train.shape[0]
batch_size = 100
learning_rate = 0.01
beta1 = 0.9
beta2 = 0.999

train_loss_list = []
accuracies_train = []
accuracies_test = []

plot_interval=10

for i in range(iters_num):
    batch_mask = np.random.choice(train_size, batch_size)
    x_batch = x_train[batch_mask]
    d_batch = d_train[batch_mask]

    # 勾配
    grad = network.gradient(x_batch, d_batch)
    if i == 0:
        m = {}
        v = {}
    learning_rate_t  = learning_rate * np.sqrt(1.0 - beta2 ** (i + 1)) / (1.0 - beta1 ** (i + 1))    
    for key in ('W1', 'W2', 'W3', 'b1', 'b2', 'b3'):
        if i == 0:
            m[key] = np.zeros_like(network.params[key])
            v[key] = np.zeros_like(network.params[key])
            
        m[key] += (1 - beta1) * (grad[key] - m[key])
        v[key] += (1 - beta2) * (grad[key] ** 2 - v[key])            
        network.params[key] -= learning_rate_t * m[key] / (np.sqrt(v[key]) + 1e-7)                
        
        
    if (i + 1) % plot_interval == 0:
        accr_test = network.accuracy(x_test, d_test)
        accuracies_test.append(accr_test)        
        accr_train = network.accuracy(x_batch, d_batch)
        accuracies_train.append(accr_train)
        loss = network.loss(x_batch, d_batch)
        train_loss_list.append(loss)        
        
    if (i + 1) > 990:
        print('Generation: ' + str(i+1) + '. 正答率(トレーニング) = ' + str(accr_train))
        print('                : ' + str(i+1) + '. 正答率(テスト) = ' + str(accr_test))
                

lists = range(0, iters_num, plot_interval)
plt.plot(lists, accuracies_train, label="training set")
plt.plot(lists, accuracies_test,  label="test set")
plt.legend(loc="lower right")
plt.title("accuracy")
plt.xlabel("count")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
# グラフの表示
plt.show()
# Out:
# データ読み込み完了
# Generation: 930. 正答率(トレーニング) = 0.99
#                 : 930. 正答率(テスト) = 0.9518
# Generation: 931. 正答率(トレーニング) = 0.99
#                 : 931. 正答率(テスト) = 0.9518
# Generation: 932. 正答率(トレーニング) = 0.99
#                 : 932. 正答率(テスト) = 0.9518
# Generation: 933. 正答率(トレーニング) = 0.99
#                 : 933. 正答率(テスト) = 0.9518
# Generation: 934. 正答率(トレーニング) = 0.99
#                 : 934. 正答率(テスト) = 0.9518
# Generation: 935. 正答率(トレーニング) = 0.99
#                 : 935. 正答率(テスト) = 0.9518
# Generation: 936. 正答率(トレーニング) = 0.99
#                 : 936. 正答率(テスト) = 0.9518
# Generation: 937. 正答率(トレーニング) = 0.99
#                 : 937. 正答率(テスト) = 0.9518
# Generation: 938. 正答率(トレーニング) = 0.99
#                 : 938. 正答率(テスト) = 0.9518
# Generation: 939. 正答率(トレーニング) = 0.99
#                 : 939. 正答率(テスト) = 0.9518
# Generation: 940. 正答率(トレーニング) = 0.98
#                 : 940. 正答率(テスト) = 0.9492
# Generation: 941. 正答率(トレーニング) = 0.98
#                 : 941. 正答率(テスト) = 0.9492
# Generation: 942. 正答率(トレーニング) = 0.98
#                 : 942. 正答率(テスト) = 0.9492
# Generation: 943. 正答率(トレーニング) = 0.98
#                 : 943. 正答率(テスト) = 0.9492
# Generation: 944. 正答率(トレーニング) = 0.98
#                 : 944. 正答率(テスト) = 0.9492
# Generation: 945. 正答率(トレーニング) = 0.98
#                 : 945. 正答率(テスト) = 0.9492
# Generation: 946. 正答率(トレーニング) = 0.98
#                 : 946. 正答率(テスト) = 0.9492
# Generation: 947. 正答率(トレーニング) = 0.98
#                 : 947. 正答率(テスト) = 0.9492
# Generation: 948. 正答率(トレーニング) = 0.98
#                 : 948. 正答率(テスト) = 0.9492
# Generation: 949. 正答率(トレーニング) = 0.98
#                 : 949. 正答率(テスト) = 0.9492
# Generation: 950. 正答率(トレーニング) = 0.95
#                 : 950. 正答率(テスト) = 0.9487
# Generation: 951. 正答率(トレーニング) = 0.95
#                 : 951. 正答率(テスト) = 0.9487
# Generation: 952. 正答率(トレーニング) = 0.95
#                 : 952. 正答率(テスト) = 0.9487
# Generation: 953. 正答率(トレーニング) = 0.95
#                 : 953. 正答率(テスト) = 0.9487
# Generation: 954. 正答率(トレーニング) = 0.95
#                 : 954. 正答率(テスト) = 0.9487
# Generation: 955. 正答率(トレーニング) = 0.95
#                 : 955. 正答率(テスト) = 0.9487
# Generation: 956. 正答率(トレーニング) = 0.95
#                 : 956. 正答率(テスト) = 0.9487
# Generation: 957. 正答率(トレーニング) = 0.95
#                 : 957. 正答率(テスト) = 0.9487
# Generation: 958. 正答率(トレーニング) = 0.95
#                 : 958. 正答率(テスト) = 0.9487
# Generation: 959. 正答率(トレーニング) = 0.95
#                 : 959. 正答率(テスト) = 0.9487
# Generation: 960. 正答率(トレーニング) = 0.97
#                 : 960. 正答率(テスト) = 0.9437
# Generation: 961. 正答率(トレーニング) = 0.97
#                 : 961. 正答率(テスト) = 0.9437
# Generation: 962. 正答率(トレーニング) = 0.97
#                 : 962. 正答率(テスト) = 0.9437
# Generation: 963. 正答率(トレーニング) = 0.97
#                 : 963. 正答率(テスト) = 0.9437
# Generation: 964. 正答率(トレーニング) = 0.97
#                 : 964. 正答率(テスト) = 0.9437
# Generation: 965. 正答率(トレーニング) = 0.97
#                 : 965. 正答率(テスト) = 0.9437
# Generation: 966. 正答率(トレーニング) = 0.97
#                 : 966. 正答率(テスト) = 0.9437
# Generation: 967. 正答率(トレーニング) = 0.97
#                 : 967. 正答率(テスト) = 0.9437
# Generation: 968. 正答率(トレーニング) = 0.97
#                 : 968. 正答率(テスト) = 0.9437
# Generation: 969. 正答率(トレーニング) = 0.97
#                 : 969. 正答率(テスト) = 0.9437
# Generation: 970. 正答率(トレーニング) = 0.98
#                 : 970. 正答率(テスト) = 0.946
# Generation: 971. 正答率(トレーニング) = 0.98
#                 : 971. 正答率(テスト) = 0.946
# Generation: 972. 正答率(トレーニング) = 0.98
#                 : 972. 正答率(テスト) = 0.946
# Generation: 973. 正答率(トレーニング) = 0.98
#                 : 973. 正答率(テスト) = 0.946
# Generation: 974. 正答率(トレーニング) = 0.98
#                 : 974. 正答率(テスト) = 0.946
# Generation: 975. 正答率(トレーニング) = 0.98
#                 : 975. 正答率(テスト) = 0.946
# Generation: 976. 正答率(トレーニング) = 0.98
#                 : 976. 正答率(テスト) = 0.946
# Generation: 977. 正答率(トレーニング) = 0.98
#                 : 977. 正答率(テスト) = 0.946
# Generation: 978. 正答率(トレーニング) = 0.98
#                 : 978. 正答率(テスト) = 0.946
# Generation: 979. 正答率(トレーニング) = 0.98
#                 : 979. 正答率(テスト) = 0.946
# Generation: 980. 正答率(トレーニング) = 0.91
#                 : 980. 正答率(テスト) = 0.9503
# Generation: 981. 正答率(トレーニング) = 0.91
#                 : 981. 正答率(テスト) = 0.9503
# Generation: 982. 正答率(トレーニング) = 0.91
#                 : 982. 正答率(テスト) = 0.9503
# Generation: 983. 正答率(トレーニング) = 0.91
#                 : 983. 正答率(テスト) = 0.9503
# Generation: 984. 正答率(トレーニング) = 0.91
#                 : 984. 正答率(テスト) = 0.9503
# Generation: 985. 正答率(トレーニング) = 0.91
#                 : 985. 正答率(テスト) = 0.9503
# Generation: 986. 正答率(トレーニング) = 0.91
#                 : 986. 正答率(テスト) = 0.9503
# Generation: 987. 正答率(トレーニング) = 0.91
#                 : 987. 正答率(テスト) = 0.9503
# Generation: 988. 正答率(トレーニング) = 0.91
#                 : 988. 正答率(テスト) = 0.9503
# Generation: 989. 正答率(トレーニング) = 0.91
#                 : 989. 正答率(テスト) = 0.9503
# Generation: 990. 正答率(トレーニング) = 0.96
#                 : 990. 正答率(テスト) = 0.9503
# Generation: 991. 正答率(トレーニング) = 0.96
#                 : 991. 正答率(テスト) = 0.9503
# Generation: 992. 正答率(トレーニング) = 0.96
#                 : 992. 正答率(テスト) = 0.9503
# Generation: 993. 正答率(トレーニング) = 0.96
#                 : 993. 正答率(テスト) = 0.9503
# Generation: 994. 正答率(トレーニング) = 0.96
#                 : 994. 正答率(テスト) = 0.9503
# Generation: 995. 正答率(トレーニング) = 0.96
#                 : 995. 正答率(テスト) = 0.9503
# Generation: 996. 正答率(トレーニング) = 0.96
#                 : 996. 正答率(テスト) = 0.9503
# Generation: 997. 正答率(トレーニング) = 0.96
#                 : 997. 正答率(テスト) = 0.9503
# Generation: 998. 正答率(トレーニング) = 0.96
#                 : 998. 正答率(テスト) = 0.9503
# Generation: 999. 正答率(トレーニング) = 0.96
#                 : 999. 正答率(テスト) = 0.9503
# Generation: 1000. 正答率(トレーニング) = 0.97
#                 : 1000. 正答率(テスト) = 0.9482

# %% [markdown]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## [try] 学習率を変えてみよう

# %% [markdown]
# ## [try] 活性化関数と重みの初期化方法を変えてみよう
# 初期状態ではsigmoid - gauss<br>
# activationはReLU、weight_init_stdは別の数値や'Xavier'・'He'に変更可能

# %% [markdown]
# ## [try] バッチ正規化をしてみよう
# use_batchnormをTrueにしよう
#
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
